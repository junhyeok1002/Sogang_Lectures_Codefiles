# %% [markdown]
# # Autocorrelation functions

# %% [markdown]
# This program computes and plots autocorrelation fucntions.

# %% [markdown]
# ## 1. Import required packages

# %%
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa import stattools

# %% [markdown]
# ## 2. Generate data

# %%
alp = 0.3
ts_length = 500
current_x = 0
x_values = []
for i in range(ts_length+1):
    x_values.append(current_x)
    current_x = alp * current_x + np.random.randn()

# %% [markdown]
# ## 3. Plot data

# %%
plt.plot(range(ts_length+1),x_values)
plt.show()

# %% [markdown]
# ## 4. Calculate ACF, q-stat and plot ACF

# %%
n_nlags=40
atcf_qs =stattools.acf(x_values,adjusted=True, nlags=n_nlags,qstat=True, fft=False, alpha=None, missing='none')
   # atcf[0] ((n_nlags+1) by 1) contains values of ACF, 
   # atcf[1] (n_nlags by 1) those of q-stat, and atcf[3] p-values of the q-stat 
temp_acf=n_nlags +1
plt.bar(range(temp_acf),atcf_qs[0])
plt.show()

# %%
n_nlags=40
atcf_qs =stattools.acf(x_values,nlags=n_nlags)
temp_acf=n_nlags +1
plt.bar(range(temp_acf),atcf_qs)
plt.show()
