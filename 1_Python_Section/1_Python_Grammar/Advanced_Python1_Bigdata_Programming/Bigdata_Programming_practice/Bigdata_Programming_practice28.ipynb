# %% [markdown]
# 20180634_최준혁_과제12: 성적처리 Pandas Version

# %%
import pandas_datareader.data as web
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

data = pd.read_csv('StuData.csv', index_col=0)
data['Com'] = pd.Series({2201:78,2202:99,2203:90,2204:45,2205:80,2206:75})
data['평균'] = round(data.iloc[:,1:].sum(axis = 1) / 4,2)
data.loc['평균'] = round(data.iloc[:,1:].sum(axis = 0) / 6, 2)

# %%
data
# Out:
#        이름     국어     영어     수학    Com     평균
# 2201  홍길일  90.00  80.00  85.00  78.00  83.25
# 2202  홍길이  90.00  85.00  90.00  99.00  91.00
# 2203  홍길삼  80.00  80.00  80.00  90.00  82.50
# 2204  홍길사  90.00  92.00  83.00  45.00  77.50
# 2205  홍길오  85.00  85.00  90.00  80.00  85.00
# 2206  홍길육  95.00  95.00  80.00  75.00  86.25
# 평균    NaN  88.33  86.17  84.67  77.83  84.25

# %%
'''from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/NGULIM.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font',family = font)''' #한글 폰트 적용시키려다가 실패

X = ['Kor','Eng','Math','Com','Avg']
plt.figure(figsize=(10,5))
for i in range(6):
    plt.xkcd()
    plt.plot(X,data.iloc[i,1:], label = data.index[i])
plt.title('Scores of each student')
plt.legend(loc = 0)

# %%
X = ['Kor','Eng','Math','Com']
plt.figure(figsize=(10,5))
plt.xkcd()
plt.plot(X,data.iloc[6,1:5])
plt.title('Average of each subject')
# Out:
# Text(0.5, 1.0, 'Average of each subject')
