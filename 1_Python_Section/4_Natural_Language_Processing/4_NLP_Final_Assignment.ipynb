# %% [markdown]
# 20180634_최준혁_NLP_기말과제

# %% [markdown]
# ## Imports & Define train/valid/test

# %%
# Import modules
import nltk
from nltk.corpus import brown

# Define train/valid/test
train = brown.tagged_sents(categories='news')
validation = brown.tagged_sents(categories='editorial')
test = brown.tagged_sents(categories='reviews')

# 카테고리 별 개수 확인
print('train(news) : ',len(brown.words(categories='news')))
print('validation(editorial) : ',len(brown.words(categories='editorial')))
print('test(reviews) : ',len(brown.words(categories='reviews')))
# Out:
# train(news) :  100554
# validation(editorial) :  61604
# test(reviews) :  40704

# %% [markdown]
# ## Performance Comparison

# %% [markdown]
# ### Default

# %%
# 여기 패턴부분을 수정하기
patterns = [('.*ing$', 'VBG'),              # gerunds 
            ('.*ed$', 'VBD'),               # simple past
            ('.*es$', 'VBZ'),               # 3rd singular present
            ('.*ould$', 'MD'),              # modals
            ('.*\'s$', 'NN$'),              # possessive nouns
            ('.*s$', 'NNS'),                # plural nouns
            ('^-?[0-9]+(.[0-9]+)?$', 'CD'), # cardinal numbers
            ('.*', 'NN')]                   # nouns (default)

# 여기 수정 불가
t0 = nltk.RegexpTagger(patterns)
t1 = nltk.UnigramTagger(train, backoff=t0)
t2 = nltk.BigramTagger(train, backoff=t1)
t3 = nltk.TrigramTagger(train, backoff=t2)

# valid, test 성능 출력
print("valid_accuracy",  t3.accuracy(validation))
print("test_accuracy",  t3.accuracy(test))
# Out:
# valid_accuracy 0.8636776832673203
# test_accuracy 0.8320066823899371

# %% [markdown]
# ### ANSWER

# %%
# 여기 패턴부분을 수정하면서 valid 성능을 확인해보고 성능 향상이 있으면 패턴변경 사항을 수용하는 방식
patterns = [
            ('.*ing$', 'VBG'),                        # 현재 분사 
            ('.*ed$', 'VBD'),                         # 과거 동사
            ('.*ould$', 'MD'),                        # 동사 조동사
            ('.*\'s$', 'NN$'),                        # 소유격 및 명사 단수
            ('.*s$', 'NNS'),                          # 복수명사
            ('^-?[0-9]+(.[0-9]+)?$', 'CD'),           # 기수 숫자
    
            # 형용사류 
            ('.*(nt|erb|ful|al|ic|[aiou]ble)$', 'JJ'),# 형용사용 어미 : 어미 빈도 분석 기반
            ('.*est$', 'JJT'),                        # 최상급 est
            
            # 부사
            ('.*ly$', 'RB'),                          # 대표적 부사형 어미 ly
            
            # 동사
            ('.*(ize|ate)$', 'VB'),                   # 동사형 어미 : 어미 빈도 분석 기반
            
            # 명사
            ('^[A-Z].*', 'NN-TL'),                    # 명사 default : 대문자로 시작하는 것은 NN-TL
            ('.*', 'NN')
            ]                             # 명사 default : 소문자로 시작하는 것은 NN

# 여기 수정 불가
t0 = nltk.RegexpTagger(patterns)
t1 = nltk.UnigramTagger(train, backoff=t0)
t2 = nltk.BigramTagger(train, backoff=t1)
t3 = nltk.TrigramTagger(train, backoff=t2)

# valid 성능 출력
print("valid_accuracy",  t3.accuracy(validation))
# Out:
# valid_accuracy 0.8758846828128044

# %%
# valid 성능을 최대한으로 끌어올린 후 test로 성능 확인
acc = t3.accuracy(test)
print("test_accuracy",  acc)

# 과제 최대 점수 확인용
if acc >= 0.85201 : print('\n목표점수(0.85201 이상)에 도달하였습니다')
else : print('목표점수(0.85201 이상)에 도달하지 못했습니다. 더 성능을 올리세요')
# Out:
# test_accuracy 0.8521766902515723
#
# 목표점수(0.85201 이상)에 도달하였습니다

# %% [markdown]
# ## 해결과정전략에 사용했던 코드들

# %%
# 명사가 가장 많으므로 default처리하고 빈도 높은 순서대로 품사별 어미파악을 진행함
print(nltk.FreqDist([tag for word, tag in \
               [tagged for row in validation for tagged in row]]).most_common(20))
# Out:
# [('NN', 7675), ('IN', 6204), ('AT', 5311), ('JJ', 3593), ('.', 2988), ('NNS', 2972), (',', 2741), ('VB', 2129), ('NP', 1884), ('CC', 1835), ('RB', 1809), ('VBN', 1491), ('CS', 1194), ('NN-TL', 1152), ('TO', 952), ('VBG', 881), ('MD', 867), ('PPS', 782), ('PP$', 771), ('BEZ', 749)]

# %%
# 품사별 어미파악하는 함수 : train_set에서 진행
# 품사를 입력하면 뒤의 4,3,2개 짜리어미가 무엇이 있는지 빈도순으로 보여준다
def umi_check(pos_tag):
    print('-'*100)
    print(f"[{pos_tag}의 어미 빈도 분석 ]")
    print("> 4개 짜리 어미 : ", end = '')
    print(nltk.FreqDist([word[-4:] for word, tag in [tagged for row in train \
                        for tagged in row] if tag == pos_tag]).most_common(10),"\n")

    print("> 3개 짜리 어미 : ", end = '')
    print(nltk.FreqDist([word[-3:] for word, tag in [tagged for row in train \
                        for tagged in row] if tag == pos_tag]).most_common(10),"\n")

    print("> 2개 짜리 어미 : ", end = '')
    print(nltk.FreqDist([word[-2:] for word, tag in [tagged for row in train \
                        for tagged in row] if tag == pos_tag]).most_common(10),"\n")
    print('-'*100)
    
umi_check("JJ")
umi_check("JJT")
umi_check("RB")
umi_check("VB")
# Out:
# ----------------------------------------------------------------------------------------------------
# [JJ의 어미 빈도 분석 ]
# > 4개 짜리 어미 : [('new', 147), ('onal', 144), ('able', 114), ('tive', 112), ('ical', 98), ('cial', 87), ('ious', 75), ('eral', 67), ('ible', 60), ('such', 51)]
#
# > 3개 짜리 어미 : [('ble', 179), ('nal', 179), ('ive', 151), ('ial', 149), ('new', 147), ('ent', 146), ('cal', 140), ('ous', 137), ('ral', 117), ('ing', 102)]
#
# > 2개 짜리 어미 : [('al', 760), ('le', 226), ('ic', 213), ('nt', 188), ('ng', 185), ('te', 157), ('ve', 154), ('ew', 150), ('us', 137), ('an', 133)]
#
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# [JJT의 어미 빈도 분석 ]
# > 4개 짜리 어미 : [('best', 26), ('gest', 25), ('test', 16), ('hest', 8), ('lest', 6), ('iest', 4), ('west', 4), ('nest', 3), ('orst', 2), ('mest', 1)]
#
# > 3개 짜리 어미 : [('est', 97), ('rst', 2), ('aid', 1)]
#
# > 2개 짜리 어미 : [('st', 99), ('id', 1)]
#
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# [RB의 어미 빈도 분석 ]
# > 4개 짜리 어미 : [('ally', 158), ('also', 120), ('here', 105), ('now', 76), ('ever', 72), ('ntly', 62), ('bout', 60), ('arly', 59), ('then', 56), ('back', 54)]
#
# > 3개 짜리 어미 : [('lly', 176), ('lso', 129), ('tly', 109), ('ere', 106), ('ely', 102), ('ver', 76), ('now', 76), ('hen', 72), ('rly', 72), ('nly', 69)]
#
# > 2개 짜리 어미 : [('ly', 717), ('so', 140), ('en', 133), ('re', 126), ('er', 116), ('ow', 91), ('st', 77), ('ll', 68), ('ut', 61), ('ck', 59)]
#
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# [VB의 어미 빈도 분석 ]
# > 4개 짜리 어미 : [('get', 66), ('take', 52), ('make', 43), ('come', 41), ('go', 40), ('see', 38), ('give', 33), ('play', 31), ('pay', 27), ('hink', 27)]
#
# > 3개 짜리 어미 : [('ake', 102), ('ive', 81), ('ate', 76), ('get', 68), ('end', 61), ('ome', 41), ('go', 40), ('see', 39), ('ide', 38), ('lay', 35)]
#
# > 2개 짜리 어미 : [('ve', 156), ('ke', 124), ('et', 119), ('te', 110), ('nd', 110), ('ay', 97), ('se', 75), ('er', 71), ('ow', 68), ('nt', 63)]
#
# ----------------------------------------------------------------------------------------------------

# %%
# 이 코드는 특정 단어가 품사가 무엇인지 검색해서 확인해보거나 
# 어떤 어미로 끝나는지 확인해보기 위한 코드
# 아래의 예시는 ly로 끝나는 단어들의 품사가 무엇인지 확인하는 것이다 -> 대부분 부사이다
[(word, tag) for word, tag in [tagged for row in test for tagged in row] if word[-2:] == 'ly']
# Out:
# [('Certainly', 'RB'),
#  ('lovely', 'JJ'),
#  ('only', 'RB'),
#  ('considerably', 'QL'),
#  ('July', 'NP'),
#  ('July', 'NP'),
#  ('July', 'NP'),
#  ('July', 'NP'),
#  ('fly', 'VB'),
#  ('firmly', 'QL'),
#  ('fly', 'VB'),
#  ('wily', 'JJ'),
#  ('blandly', 'QL'),
#  ('atrociously', 'QL'),
#  ('precisely', 'RB'),
#  ('hardly', 'QL'),
#  ('really', 'RB'),
#  ('really', 'RB'),
#  ('probably', 'RB'),
#  ('wonderfully', 'QL'),
#  ('Piccadilly', 'NP'),
#  ('truly', 'RB'),
#  ('only', 'RB'),
#  ('family', 'NN'),
#  ('apparently', 'RB'),
#  ('entirely', 'QL'),
#  ('truly', 'QL'),
#  ('inevitably', 'RB'),
#  ('affectingly', 'RB'),
#  ('soberly', 'RB'),
#  ('sincerely', 'RB'),
#  ('studiously', 'QL'),
#  ('brightly', 'RB'),
#  ('gravely', 'RB'),
#  ('considerably', 'RB'),
#  ('appropriately', 'QL'),
#  ('excellently', 'RB'),
#  ('helpfully', 'RB'),
#  ('comically', 'RB'),
#  ('really', 'RB'),
#  ('facetiously', 'RB'),
#  ('finely', 'QL'),
#  ('magnificently', 'QL'),
#  ('family', 'NN'),
#  ('necessarily', 'RB'),
#  ('considerately', 'RB'),
#  ('hardly', 'RB'),
#  ('cleverly', 'RB'),
#  ('unfortunately', 'RB'),
#  ('probably', 'RB'),
#  ('Similarly', 'RB'),
#  ('early', 'JJ'),
#  ('happily', 'RB'),
#  ('finally', 'RB'),
#  ('brilliantly', 'RB'),
#  ('probably', 'RB'),
#  ('superbly', 'QL'),
#  ('slowly', 'RB'),
#  ('magnificently', 'RB'),
#  ('Technically', 'RB'),
#  ('aurally', 'RB'),
#  ('dramatically', 'RB'),
#  ('equally', 'QL'),
#  ('satisfactorily', 'RB'),
#  ('only', 'RB'),
#  ('really', 'RB'),
#  ('preferably', 'RB'),
#  ('fairly', 'QL'),
#  ('greatly', 'RB'),
#  ('definitely', 'RB'),
#  ('apparently', 'RB'),
#  ('merely', 'RB'),
#  ('immediately', 'RB'),
#  ('remarkably', 'RB'),
#  ('Only', 'RB'),
#  ('definitely', 'RB'),
#  ('apparently', 'RB'),
#  ('gratifyingly', 'QL'),
#  ('practically', 'RB'),
#  ('physically', 'RB'),
#  ('impeccably', 'RB'),
#  ('recently', 'RB'),
#  ('only', 'AP'),
#  ('lavishly', 'RB'),
#  ('hardly', 'RB'),
#  ('wildly', 'RB'),
#  ('meticulously', 'QL'),
#  ('finally', 'RB'),
#  ('totally', 'RB'),
#  ('partially', 'RB'),
#  ('noisily', 'RB'),
#  ('overly', 'QL'),
#  ('melodically', 'QL'),
#  ('brightly', 'QL'),
#  ('especially', 'QL'),
#  ('simultaneously', 'RB'),
#  ('nicely', 'RB'),
#  ('unfailingly', 'QL'),
#  ('only', 'RB'),
#  ('necessarily', 'RB'),
#  ('only', 'RB'),
#  ('heavily', 'RB'),
#  ('originally', 'RB'),
#  ('bitterly', 'RB'),
#  ('exceptionally', 'QL'),
#  ('generously', 'RB'),
#  ('lively', 'JJ'),
#  ('rally', 'VB'),
#  ('supply', 'NN'),
#  ('accordingly', 'RB'),
#  ('only', 'RB'),
#  ('equally', 'QL'),
#  ('usually', 'RB'),
#  ('uncomplainingly', 'RB'),
#  ('Actually', 'RB'),
#  ('beautifully', 'RB'),
#  ('lovely', 'JJ'),
#  ('extremely', 'QL'),
#  ('remarkably', 'QL'),
#  ('generally', 'RB'),
#  ('only', 'RB'),
#  ('neatly', 'RB'),
#  ('lively', 'RB'),
#  ('enchantingly', 'RB'),
#  ('thoroughly', 'QL'),
#  ('suddenly', 'RB'),
#  ('definitely', 'RB'),
#  ('simply', 'RB'),
#  ('basically', 'RB'),
#  ('selectively', 'RB'),
#  ('specifically', 'RB'),
#  ('professionally', 'RB'),
#  ('equally', 'QL'),
#  ('likely', 'JJ'),
#  ('wonderfully', 'QL'),
#  ('constantly', 'RB'),
#  ('only', 'RB'),
#  ('only', 'AP'),
#  ('conspicuously', 'RB'),
#  ('likely', 'RB'),
#  ('virtually', 'QL'),
#  ('nearly', 'RB'),
#  ('Billy', 'NP'),
#  ('lively', 'JJ'),
#  ('constantly', 'RB'),
#  ('family', 'NN'),
#  ('only', 'RB'),
#  ('only', 'RB'),
#  ('awfully', 'QL'),
#  ('terribly', 'QL'),
#  ('technically', 'RB'),
#  ('lovely', 'JJ'),
#  ('intensely', 'QL'),
#  ('usually', 'RB'),
#  ('tantalizingly', 'RB'),
#  ('greatly', 'RB'),
#  ('only', 'AP'),
#  ('lively', 'JJ'),
#  ('especially', 'RB'),
#  ('suitably', 'QL'),
#  ('positively', 'QL'),
#  ('only', 'RB'),
#  ('Certainly', 'RB'),
#  ('really', 'RB'),
#  ('simply', 'RB'),
#  ('splendidly', 'RB'),
#  ('really', 'QL'),
#  ('visibly', 'RB'),
#  ('remarkably', 'RB'),
#  ('recently', 'RB'),
#  ('highly', 'QL'),
#  ('probably', 'RB'),
#  ('fairly', 'QL'),
#  ('honestly', 'RB'),
#  ('commonly', 'RB'),
#  ('reasonably', 'RB'),
#  ('healthily', 'RB'),
#  ('exactly', 'QL'),
#  ('hilariously', 'RB'),
#  ('only', 'AP'),
#  ('admirably', 'RB'),
#  ('surely', 'RB'),
#  ('subtly', 'RB'),
#  ('elegantly', 'RB'),
#  ('surely', 'RB'),
#  ('warmly', 'QL'),
#  ('certainly', 'RB'),
#  ('equally', 'QL'),
#  ('radically', 'RB'),
#  ('importantly', 'RB'),
#  ('recently', 'RB'),
#  ('absolutely', 'RB'),
#  ('literally', 'RB'),
#  ('only', 'RB'),
#  ('really', 'RB'),
#  ('exclusively', 'RB'),
#  ('reply', 'VB'),
#  ('reply', 'VB'),
#  ('generally', 'RB'),
#  ('singly', 'RB'),
#  ('impersonally', 'RB'),
#  ('simply', 'RB'),
#  ('positively', 'RB'),
#  ('quietly', 'RB'),
#  ('equally', 'QL'),
#  ('slightly', 'RB'),
#  ('cunningly', 'RB'),
#  ('sadly', 'RB'),
#  ('rely', 'VB'),
#  ('scholarly', 'JJ'),
#  ('only', 'RB'),
#  ('brilliantly', 'RB'),
#  ('amusingly', 'QL'),
#  ('only', 'RB'),
#  ('keenly', 'QL'),
#  ('namely', 'RB'),
#  ('Equally', 'RB'),
#  ('mildly', 'QL'),
#  ('terribly', 'QL'),
#  ('July', 'NP'),
#  ('reassuringly', 'RB'),
#  ('artistically', 'RB'),
#  ('literally', 'RB'),
#  ('early', 'JJ'),
#  ('easily', 'RB'),
#  ('only', 'RB'),
#  ('rarely', 'RB'),
#  ('capably', 'QL'),
#  ('differently', 'RB'),
#  ('splendidly', 'QL'),
#  ('only', 'RB'),
#  ('moderately', 'QL'),
#  ('invariably', 'RB'),
#  ('really', 'QL'),
#  ('largely', 'RB'),
#  ('uncommonly', 'QL'),
#  ('highly', 'QL'),
#  ('sweepingly', 'RB'),
#  ('subsequently', 'RB'),
#  ('simply', 'RB'),
#  ('exclusively', 'RB'),
#  ('only', 'RB'),
#  ('absolutely', 'RB'),
#  ('nearly', 'RB'),
#  ('only', 'RB'),
#  ('easily', 'RB'),
#  ('justly', 'RB'),
#  ('grossly', 'RB'),
#  ('effectively', 'RB'),
#  ('apparently', 'RB'),
#  ('generally', 'RB'),
#  ('wily', 'JJ'),
#  ('recently', 'RB'),
#  ('recently', 'RB'),
#  ('only', 'AP'),
#  ('vitally', 'QL'),
#  ('usually', 'RB'),
#  ('occasionally', 'RB'),
#  ('lively', 'JJ'),
#  ('accidentally', 'RB'),
#  ('considerably', 'RB'),
#  ('happily', 'RB'),
#  ('immensely', 'RB'),
#  ('practically', 'QL'),
#  ('naturally', 'RB'),
#  ('only', 'RB'),
#  ('really', 'RB'),
#  ('Sibly', 'NP'),
#  ('sufficiently', 'RB'),
#  ('only', 'RB'),
#  ('generally', 'RB'),
#  ('authentically', 'RB'),
#  ('permanently', 'RB'),
#  ('easily', 'RB'),
#  ('easily', 'RB'),
#  ('easily', 'RB'),
#  ('joyously', 'RB'),
#  ('substantially', 'QL'),
#  ('apparently', 'RB'),
#  ('nicely', 'RB'),
#  ('evenly', 'RB'),
#  ('properly', 'RB'),
#  ('heavily', 'QL'),
#  ('tonally', 'RB'),
#  ('exactly', 'RB'),
#  ('fully', 'RB'),
#  ('oily', 'JJ'),
#  ('only', 'RB'),
#  ('magnificently', 'RB'),
#  ('unfortunately', 'RB'),
#  ('only', 'RB'),
#  ('Italy', 'NP'),
#  ('Early', 'JJ-HL'),
#  ('Naturally', 'RB'),
#  ('squarely', 'RB'),
#  ('Only', 'RB'),
#  ('excellently', 'RB'),
#  ('chronologically', 'RB'),
#  ('Italy', 'NP'),
#  ('lively', 'JJ'),
#  ('nearly', 'RB'),
#  ('unlikely', 'JJ'),
#  ('naturally', 'RB'),
#  ('really', 'QL'),
#  ('elaborately', 'RB'),
#  ('hardly', 'RB'),
#  ('apparently', 'RB'),
#  ('really', 'RB'),
#  ('generally', 'QL'),
#  ('exclusively', 'RB'),
#  ('pleasingly', 'QL'),
#  ('silly', 'JJ'),
#  ('largely', 'RB'),
#  ('virtually', 'RB'),
#  ('mostly', 'RB'),
#  ('terribly', 'RB'),
#  ('recently', 'RB'),
#  ('Certainly', 'RB'),
#  ('only', 'RB'),
#  ('lovely', 'JJ'),
#  ('only', 'RB'),
#  ('fortunately', 'RB'),
#  ('really', 'RB'),
#  ('horribly', 'QL'),
#  ('shatteringly', 'QL'),
#  ('really', 'QL'),
#  ('deeply', 'RB'),
#  ('equally', 'RB'),
#  ('lovely', 'JJ'),
#  ('equally', 'RB'),
#  ('intensely', 'RB'),
#  ('Unfortunately', 'RB'),
#  ('only', 'RB'),
#  ('briefly', 'RB'),
#  ('only', 'RB'),
#  ('gradually', 'RB'),
#  ('lovely', 'JJ'),
#  ('principally', 'RB'),
#  ('especially', 'RB'),
#  ('equally', 'RB'),
#  ('early', 'JJ'),
#  ('extremely', 'QL'),
#  ('beautifully', 'RB'),
#  ('truly', 'QL'),
#  ('frequently', 'RB'),
#  ('Billy', 'NP'),
#  ('likely', 'RB'),
#  ('beautifully', 'RB'),
#  ('superbly', 'RB'),
#  ('roughly', 'RB'),
#  ('necessarily', 'RB'),
#  ('frequently', 'RB'),
#  ('consciously', 'RB'),
#  ('merely', 'RB'),
#  ('sprightly', 'JJ'),
#  ('refreshingly', 'RB'),
#  ('Unfortunately', 'RB'),
#  ('really', 'RB'),
#  ('greatly', 'RB'),
#  ('recently', 'RB'),
#  ('obviously', 'RB'),
#  ('responsively', 'RB'),
#  ('really', 'RB'),
#  ('casually', 'RB'),
#  ('shortly', 'RB'),
#  ('finally', 'RB'),
#  ('likely', 'JJ'),
#  ('permanently', 'RB'),
#  ('constantly', 'RB'),
#  ('delightfully', 'RB'),
#  ('virtually', 'QL'),
#  ('extremely', 'QL'),
#  ('widely', 'RB'),
#  ('Really', 'RB-TL'),
#  ('scarcely', 'RB'),
#  ('comically', 'RB'),
#  ('only', 'AP'),
#  ('remarkably', 'QL'),
#  ('warmly', 'RB'),
#  ('Molly', 'NP'),
#  ('only', 'RB'),
#  ('pleasantly', 'RB'),
#  ('usually', 'RB'),
#  ('persuasively', 'QL'),
#  ('simply', 'RB'),
#  ('aptly', 'QL'),
#  ('carefully', 'RB'),
#  ('genuinely', 'RB'),
#  ('strictly', 'RB'),
#  ('compassionately', 'RB'),
#  ('Unfortunately', 'RB'),
#  ('Tenderly', 'RB'),
#  ('tediously', 'RB'),
#  ('stirringly', 'RB'),
#  ('silently', 'RB'),
#  ('Only', 'RB'),
#  ('warmly', 'RB'),
#  ('only', 'RB'),
#  ('Systematically', 'RB'),
#  ('nearly', 'RB'),
#  ('only', 'RB'),
#  ('sharply', 'QL'),
#  ('suddenly', 'RB'),
#  ('implicitly', 'RB'),
#  ('merely', 'RB'),
#  ('accurately', 'RB'),
#  ('continually', 'RB'),
#  ('only', 'RB'),
#  ('occasionally', 'RB'),
#  ('frequently', 'RB'),
#  ('fairly', 'QL'),
#  ('excessively', 'QL'),
#  ('stately', 'JJ'),
#  ('possibly', 'RB'),
#  ('mainly', 'QL'),
#  ('increasingly', 'QL'),
#  ('obviously', 'RB'),
#  ('Apparently', 'RB'),
#  ('apparently', 'RB'),
#  ('shortly', 'RB'),
#  ('Accordingly', 'RB'),
#  ('truly', 'RB'),
#  ('only', 'AP'),
#  ('slowly', 'RB'),
#  ('Wisely', 'RB'),
#  ('formerly', 'RB'),
#  ('merely', 'RB'),
#  ('Occasionally', 'RB'),
#  ('justly', 'RB'),
#  ('frequently', 'RB'),
#  ('sly', 'JJ'),
#  ('persuasively', 'RB'),
#  ('unfortunately', 'RB'),
#  ('probably', 'RB'),
#  ('probably', 'RB'),
#  ('surely', 'RB'),
#  ('conclusively', 'RB'),
#  ('hardly', 'RB'),
#  ('startlingly', 'QL'),
#  ('Grappelly', 'NP'),
#  ('Grappely', 'NP'),
#  ('truthfully', 'RB'),
#  ('purely', 'RB'),
#  ('Mostly', 'RB'),
#  ('lively', 'JJ'),
#  ('lively', 'JJ'),
#  ('unlikely', 'JJ'),
#  ('glumly', 'RB'),
#  ('July', 'NP-HL'),
#  ('Only', 'RB'),
#  ('finally', 'RB'),
#  ('only', 'RB'),
#  ('extraordinarily', 'QL'),
#  ('naturally', 'RB'),
#  ('stunningly', 'RB'),
#  ('lovely', 'JJ'),
#  ('only', 'RB'),
#  ('alternately', 'RB'),
#  ('humiliatingly', 'QL'),
#  ('astonishingly', 'QL'),
#  ('only', 'RB'),
#  ('only', 'RB'),
#  ('crisply', 'RB'),
#  ('continuously', 'RB'),
#  ('highly', 'QL'),
#  ('family', 'NN'),
#  ('bluntly', 'QL'),
#  ('frequently', 'RB'),
#  ('Rarely', 'RB'),
#  ('only', 'RB'),
#  ('superbly', 'QL'),
#  ('quickly', 'RB'),
#  ('profoundly', 'RB'),
#  ('wonderfully', 'QL'),
#  ('constantly', 'RB'),
#  ('simply', 'RB'),
#  ('Lily', 'NP'),
#  ('certainly', 'RB'),
#  ('suddenly', 'RB'),
#  ('inexorably', 'RB'),
#  ('shakily', 'RB'),
#  ('beautifully', 'RB'),
#  ('intelligently', 'RB'),
#  ('easily', 'RB'),
#  ('wholly', 'RB'),
#  ('partly', 'RB'),
#  ('rarely', 'RB'),
#  ('simply', 'RB'),
#  ('predominately', 'RB'),
#  ('Recently', 'RB'),
#  ('inevitably', 'RB'),
#  ('fully', 'QL'),
#  ('only', 'RB'),
#  ('rarely', 'RB'),
#  ('frequently', 'RB'),
#  ('originally', 'RB'),
#  ('eloquently', 'RB'),
#  ('vitally', 'RB'),
#  ('early', 'JJ'),
#  ('family', 'NN'),
#  ('Obviously', 'RB'),
#  ('early', 'JJ'),
#  ('early', 'RB'),
#  ('early', 'JJ'),
#  ('finally', 'RB'),
#  ('typically', 'RB'),
#  ('only', 'AP'),
#  ('briefly', 'RB'),
#  ('primarily', 'RB'),
#  ('greatly', 'RB'),
#  ('likely', 'JJ'),
#  ('only', 'AP'),
#  ('recently', 'RB'),
#  ('fluently', 'RB'),
#  ('logically', 'RB'),
#  ('dynamically', 'QL'),
#  ('inwardly', 'RB'),
#  ('genuinely', 'QL'),
#  ('kindly', 'RB'),
#  ('only', 'QL'),
#  ('recently', 'RB'),
#  ('considerably', 'RB'),
#  ('relatively', 'QL'),
#  ('finally', 'RB'),
#  ('eventually', 'RB'),
#  ('totally', 'QL'),
#  ('thinly', 'RB'),
#  ('continually', 'RB'),
#  ('only', 'RB'),
#  ('exactly', 'QL'),
#  ('slightly', 'QL'),
#  ('presently', 'RB'),
#  ('reasonably', 'RB'),
#  ('only', 'RB'),
#  ('hopefully', 'RB'),
#  ('Presently', 'RB'),
#  ('seriously', 'RB'),
#  ('rationally', 'QL'),
#  ('Highly', 'QL'),
#  ('relentlessly', 'QL'),
#  ('Only', 'RB'),
#  ('openly', 'RB'),
#  ('actually', 'RB'),
#  ('commonly', 'RB'),
#  ('family', 'NN'),
#  ('family', 'NN'),
#  ('apparently', 'RB'),
#  ('fairly', 'QL'),
#  ('bravely', 'RB'),
#  ('resourcefully', 'RB'),
#  ('easily', 'RB'),
#  ('hardly', 'RB'),
#  ('heavily', 'RB'),
#  ('happily', 'RB'),
#  ('hardly', 'RB'),
#  ('attractively', 'RB'),
#  ('magnificently', 'RB'),
#  ('recently', 'RB'),
#  ('overly', 'QL'),
#  ('sensibly', 'RB'),
#  ('apparently', 'RB'),
#  ('additionally', 'RB'),
#  ('handsomely', 'RB'),
#  ('particularly', 'RB'),
#  ('wondrously', 'QL'),
#  ('invariably', 'RB'),
#  ('formidably', 'QL'),
#  ('only', 'AP'),
#  ('originally', 'RB'),
#  ('actually', 'RB'),
#  ('gracefully', 'RB'),
#  ('really', 'RB'),
#  ('only', 'QL'),
#  ('rarely', 'RB'),
#  ('hardly', 'QL'),
#  ('only', 'RB'),
#  ('frequently', 'RB'),
#  ('certainly', 'RB'),
#  ('easily', 'RB'),
#  ('directly', 'RB'),
#  ('Unfortunately', 'RB'),
#  ('particularly', 'RB'),
#  ('family', 'NN'),
#  ('inevitably', 'RB'),
#  ('busily', 'RB'),
#  ('conceivably', 'RB'),
#  ('badly', 'RB'),
#  ('weekly', 'RB'),
#  ('probably', 'RB'),
#  ('intelligently', 'RB'),
#  ('regularly', 'RB'),
#  ('simply', 'RB'),
#  ('steadily', 'RB'),
#  ('lovely', 'JJ'),
#  ('relatively', 'QL'),
#  ('only', 'AP'),
#  ('fairly', 'QL'),
#  ('really', 'RB'),
#  ('especially', 'RB'),
#  ('early', 'JJ'),
#  ('early', 'JJ'),
#  ('notably', 'RB'),
#  ('especially', 'RB'),
#  ('early', 'JJ'),
#  ('sharply', 'QL'),
#  ('annually', 'RB'),
#  ('heavily', 'RB'),
#  ('thoroughly', 'RB'),
#  ('eagerly', 'RB'),
#  ('lovely', 'JJ'),
#  ('occasionally', 'RB'),
#  ('probably', 'RB'),
#  ('pitilessly', 'RB'),
#  ('honestly', 'RB'),
#  ('Italy', 'NP'),
#  ('lovely', 'JJ'),
#  ('slowly', 'RB'),
#  ('casually', 'RB'),
#  ('beautifully', 'RB'),
#  ('freely', 'RB'),
#  ('only', 'RB'),
#  ('only', 'RB'),
#  ('reasonably', 'QL'),
#  ('Unhappily', 'RB'),
#  ('presumably', 'RB'),
#  ('merely', 'RB'),
#  ('distinctly', 'RB'),
#  ('actuarially', 'RB'),
#  ('obviously', 'RB'),
#  ('reasonably', 'RB'),
#  ('only', 'AP'),
#  ('only', 'RB'),
#  ('inevitably', 'RB'),
#  ('nearly', 'RB'),
#  ('only', 'RB'),
#  ('ably', 'RB'),
#  ('really', 'RB'),
#  ('only', 'RB'),
#  ('intensely', 'QL'),
#  ('particularly', 'RB'),
#  ('generously', 'RB'),
#  ('generally', 'RB'),
#  ('compulsively', 'RB'),
#  ('really', 'RB'),
#  ('basically', 'RB'),
#  ('only', 'RB'),
#  ('likely', 'JJ'),
#  ('clearly', 'RB'),
#  ('namely', 'RB'),
#  ('politically', 'RB'),
#  ('drastically', 'RB'),
#  ('carefully', 'RB'),
#  ('orderly', 'JJ'),
#  ('particularly', 'RB'),
#  ('morally', 'RB'),
#  ('aptly', 'RB'),
#  ('possibly', 'RB'),
#  ('largely', 'QL'),
#  ('equally', 'QL'),
#  ('courageously', 'RB'),
#  ('wisely', 'RB'),
#  ('only', 'RB'),
#  ('only', 'RB'),
#  ('traditionally', 'RB'),
#  ('nearly', 'QL'),
#  ('mostly', 'RB'),
#  ('inconspicuously', 'RB'),
#  ('only', 'RB'),
#  ('supply', 'VB'),
#  ('firmly', 'RB'),
#  ('meticulously', 'RB'),
#  ('likely', 'JJ'),
#  ('daily', 'JJ'),
#  ('early', 'RB'),
#  ('belly', 'NN'),
#  ('virtually', 'RB'),
#  ('particularly', 'QL'),
#  ('Physiologically', 'RB'),
#  ('permanently', 'RB'),
#  ('nearly', 'RB'),
#  ('frequently', 'RB'),
#  ('simply', 'RB'),
#  ('fairly', 'QL'),
#  ('rarely', 'RB'),
#  ('flatly', 'RB'),
#  ('currently', 'RB'),
#  ('only', 'RB'),
#  ('chemically', 'RB'),
#  ('fully', 'RB'),
#  ('partly', 'RB'),
#  ('mainly', 'RB'),
#  ('Eventually', 'RB'),
#  ('commonly', 'RB'),
#  ('permanently', 'RB'),
#  ('fatally', 'RB'),
#  ('Ordinarily', 'RB'),
#  ('only', 'RB'),
#  ('materially', 'RB'),
#  ('slowly', 'RB'),
#  ('neatly', 'RB'),
#  ('increasingly', 'QL'),
#  ('radically', 'RB'),
#  ('radically', 'QL')]
